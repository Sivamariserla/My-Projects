# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivamariserla/My-Projects/blob/main/Google_Play_Store%20Anlaysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name : GOOGLE PLAY STORE ANALYSIS**

# %% [markdown]
# ## **Description**

# %% [markdown]
# Google Play, also known as the Google Play Store or Play Store and formerly known as Android Market, is a digital distribution service operated and developed by Google.Google Play has also served as a digital media store, offering games, music, books, movies, and television programs.
# * Perform exploratory data analysis (EDA) to understand the distribution of apps based on category, size, and pricing.
# * Identify trends and patterns in user ratings and reviews to determine what makes an app popular.
# * Analyze relationships between app features (e.g., category, size, content rating) and their success metrics (e.g., rating, installs).
# * Investigate pricing models (free vs. paid apps) and their impact on downloads and ratings.
# * Use sentiment analysis on user reviews to determine common feedback themes and app sentiment.

# %% [markdown]
# ## **Data Source**

# %% [markdown]
# The analysis will utilize datasets containing information about apps from the Google Play Store, which may include fields like:
#
# * App name
# * Category
# * Rating
# * Reviews
# * Size
# * Installs
# * Type (Free/Paid)
# * Price
# * Content Rating
# * genres
# * Current Version
# * Android Version

# %% [markdown]
# ## **EDA --Google play store anlaysis begins**

# %%
import numpy as np
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.set_option("display.max_columns",None)   #It will gives the Columns in a correct formate

# %%
import pandas as pd
df=pd.read_csv("/content/googleplaystore.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## **1. Find Total Number Apps in Google Play Store**

# %%
df.shape
print("Total Number Apps in Google Play Store=",df.shape[0])
# Out:
# Total Number Apps in Google Play Store= 10841

# %% [markdown]
# ## **2. Find the Total Number of Columns in Each app of Google Play Store**

# %%
df.shape
print("Total Number of Columns in Each app of Google Play Store=",df.shape[1])
# Out:
# Total Number of Columns in Each app of Google Play Store= 13

# %% [markdown]
# ## **3. Display Top 5 Rows of The Dataset**

# %%
df.head() # By default it gives the five top rows
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ## **4.Display the last 3 rows**

# %%
df.tail(3)
# Out:
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# 10839  Varies with device
# ...

# %% [markdown]
# ## **5.Get Overall Statistics About The Data frame**

# %%
print("Statistics Details About The Data frame")
df.describe()
# Out:
# Statistics Details About The Data frame
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ## **6. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ## **7. Total Number of App Titles Contain Astrology**

# %%
df.App.str.contains('Astrology') # It gives boolean values
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840     True
# Name: App, Length: 10841, dtype: bool

# %%
df[df['App'].str.contains('Astrology',case=False)]['App']
# Out:
# 1570     Horoscopes – Daily Zodiac Horoscope and Astrology
# 1592                သိင်္ Astrology - Min Thein Kha BayDin
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, dtype: object

# %% [markdown]
# ## **8.Find Average App Rating**

# %%
df['Rating']
print(" Average App Rating=",df["Rating"].mean())
# Out:
#  Average App Rating= 4.193338315362443

# %% [markdown]
# ## **9.Find Total Number of Unique Categor**y

# %%
df['Category']
print("Total Number of Unique Category=",df["Category"].nunique())
# Out:
# Total Number of Unique Category= 34

# %% [markdown]
# ## **10.Which Category Getting The Highest Average Rating?**

# %%
print(df.groupby("Category")["Rating"].mean())
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# MAPS_AND_NAVIGATION     4.051613
# MEDICAL                 4.189143
# NEWS_AND_MAGAZINES      4.132189
# PARENTING               4.300000
# PERSONALIZATION         4.335987
# PHOTOGRAPHY             4.192114
# PRODUCTIVITY            4.211396
# SHOPPING                4.259664
# ...

# %%
# Sorting the values in the highest rating category
print(df.groupby("Category")["Rating"].mean().sort_values(ascending=False))
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %% [markdown]
# ## **11.Find Total Number of App having 5 Star Rating**

# %%
#Step-1 Get the App names by Passing the Boolean Values to DataFrame
df[df["Rating"]==5][["App","Rating"]]
# Out:
#                                               App  Rating
# 329                  Hojiboy Tojiboyev Life Hacks     5.0
# 612                 American Girls Mobile Numbers     5.0
# 615                                  Awake Dating     5.0
# 633                         Spine- The dating app     5.0
# 636    Girls Live Talk - Free Text and Video Chat     5.0
# ...                                           ...     ...
# 10721                           Mad Dash Fo' Cash     5.0
# 10742                       GKPB FP Online Church     5.0
# 10776                            Monster Ride Pro     5.0
# 10820                             Fr. Daoud Lamei     5.0
# 10837            Fr. Mike Schmitz Audio Teachings     5.0
#
# [274 rows x 2 columns]

# %%
#Step-2 Get Total Number of App names having 5 star rating
df["Rating"]==5
print("Total Number of App names having 5 star rating=",len(df[df["Rating"]==5]))
# Out:
# Total Number of App names having 5 star rating= 274

# %% [markdown]
# ## **12. Find Average Value of Reviews**

# %%
#Step-1
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
#Step-2 : converting Object type into "int" or 'float'
#df["Reviews"].astype("float") # gives ValueError bcoz one col contains 3.0M

# %%
#Step-3
df[df["Reviews"]=="3.0M"]
# so,we replace tthe value
df['Reviews']=df["Reviews"].replace('3.0M','3.0')
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# Check weather it replaced or not
df[df["Reviews"]=='3.0']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0     3.0
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#Step-4: converting Object type into "int" or 'float'
df['Reviews']=df['Reviews'].astype('float')

# %%
#Step-5 : Now to get Average review, we apply mean()
print("Average Reviews=",df["Reviews"].mean())
# Out:
# Average Reviews= 444111.9265750392

# %% [markdown]
# ## **13. Find Total Number of Free and Paid Apps**

# %%
df[df['Type']=='Free']
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %% [markdown]
# ## **14.Which App Has Maximum Reviews?**

# %%
#Step-1: Get the Max Review Values
df["Reviews"].max() # gets max value of Review
# Out:
# '9992'

# %%
#Step-2: Get the complete app details
df[df["Reviews"].max()==df["Reviews"]]
# Out:
#                          App Category  Rating Reviews Size    Installs  Type  \
# 2989  GollerCepte Live Score   SPORTS     4.2    9992  31M  1,000,000+  Free
#
#      Price Content Rating  Genres  Last Updated Current Ver Android Ver
# 2989     0       Everyone  Sports  May 23, 2018         6.5  4.1 and up

# %%
#Step-3: Get App Name which is having Maximum Review
df[df["Reviews"].max()==df["Reviews"]]["App"] # gets app name
# Out:
# 2989    GollerCepte Live Score
# Name: App, dtype: object

# %% [markdown]
# ## **15.Find the Top 5 App Names having highest Review**

# %%
#Step-2: Find the Review Values
 #df["Reviews"]
#Step-3: Sort Review Values
df["Reviews"].sort_values(ascending=False)
#Step-4: Now get 5 top App values after sorting
df["Reviews"].sort_values(ascending=False).head()
# Out:
# 2989    9992
# 4970     999
# 2723    9975
# 2705    9975
# 3079    9971
# Name: Reviews, dtype: object

# %% [markdown]
# ## **16.Find Average Rating of Free and Paid Apps**

# %%
#Step-1: Separate OR group the DataFrame Values by "Type" Column
df.groupby("Type")
#Step-2: Find the  Rating values of Each Category / Group
df.groupby("Type")["Rating"]#Here we get  Rating values of each category of "type"
#Step-3: Find the mean on the above
df.groupby("Type")["Rating"].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This analysis provides actionable insights for developers, marketers, and stakeholders in the app development ecosystem. By focusing on user design, optimizing app performancewith popular categories, businesses can significantly enhance their app’s market performance. Future work could focus on predictive modeling to anticipate user preferences and optimize app launches based on trending data.
